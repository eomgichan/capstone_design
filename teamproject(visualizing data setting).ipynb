# %%
import pandas as pd

# %%
last_result = pd.read_csv("last_result.csv", index_col = 0)
last_result
# Out:
#    우식경험유치수  충전 유치수  우식경험유치면수  충전 유치면수  영구치우식유병자여부  우식 유치수  우식 유치면수
# 0    252.0   212.0     197.0    212.0       858.0   858.0    858.0
# 1    550.0   595.0     326.0    362.0       698.0   564.0    544.0
# 2    453.0   464.0     279.0    283.0         0.0   109.0    117.0
# 3    301.0   285.0     754.0    699.0         0.0    25.0     37.0

# %%
sum_cost = sum(last_result1)
total_cost = pd.DataFrame({'충치가 있을 경우의 수 합': [sum_cost,sum_cost,sum_cost,sum_cost]})
total_cost
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10568/3083670781.py in <module>
# ----> 1 sum_cost = sum(last_result1)
#       2 total_cost = pd.DataFrame({'충치가 있을 경우의 수 합': [sum_cost,sum_cost,sum_cost,sum_cost]})
#       3 total_cost
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
last_result1 = pd.concat([last_result,total_cost],axis=1)
last_result1
# Out:
#    우식경험유치수  충전 유치수  우식경험유치면수  충전 유치면수  영구치우식유병자여부  우식 유치수  우식 유치면수  \
# 0    252.0   212.0     197.0    212.0       858.0   858.0    858.0
# 1    550.0   595.0     326.0    362.0       698.0   564.0    544.0
# 2    453.0   464.0     279.0    283.0         0.0   109.0    117.0
# 3    301.0   285.0     754.0    699.0         0.0    25.0     37.0
#
#    충치가 있을 경우의 수 합
# 0          1556.0
# 1          1556.0
# 2          1556.0
# 3          1556.0

# %%
last_result1['현재까지 충치가 생겼던 유치수에 따른 충치발생 확률'] = last_result1['우식경험유치수'] / last_result1['충치가 있을 경우의 수 합'] 

last_result2 = last_result1.drop(['우식경험유치수'], axis=1)
last_result2 = last_result2.drop(['충치가 생겼던 유치수에 따른 충치 유무','충치가 생겼던 유치수에 따른 충치발생 확률'], axis=1)
last_result2
# Out:
#    충전 유치수  우식경험유치면수  충전 유치면수  영구치우식유병자여부  우식 유치수  우식 유치면수  충치가 있을 경우의 수 합  \
# 0   212.0     197.0    212.0       858.0   858.0    858.0          1556.0
# 1   595.0     326.0    362.0       698.0   564.0    544.0          1556.0
# 2   464.0     279.0    283.0         0.0   109.0    117.0          1556.0
# 3   285.0     754.0    699.0         0.0    25.0     37.0          1556.0
#
#    현재까지 충치가 생겼던 유치수에 따른 충치발생 확률
# 0                      0.161954
# 1                      0.353470
# 2                      0.291131
# 3                      0.193445

# %%
last_result2['치료 받았던 유치의 충치 수에 따른 충치발생 확률'] = last_result2['충전 유치수'] / last_result2['충치가 있을 경우의 수 합'] 

last_result3 = last_result2.drop(['충전 유치수'], axis=1)
last_result3
# Out:
#    우식경험유치면수  충전 유치면수  영구치우식유병자여부  우식 유치수  우식 유치면수  충치가 있을 경우의 수 합  \
# 0     197.0    212.0       858.0   858.0    858.0          1556.0
# 1     326.0    362.0       698.0   564.0    544.0          1556.0
# 2     279.0    283.0         0.0   109.0    117.0          1556.0
# 3     754.0    699.0         0.0    25.0     37.0          1556.0
#
#    현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  치료 받았던 유치의 충치 수에 따른 충치발생 확률
# 0                      0.161954                     0.136247
# 1                      0.353470                     0.382391
# 2                      0.291131                     0.298201
# 3                      0.193445                     0.183162

# %%
last_result3['현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률'] = last_result3['우식경험유치면수'] / last_result3['충치가 있을 경우의 수 합'] 

last_result4 = last_result3.drop(['우식경험유치면수'], axis=1)
last_result4
# Out:
#    충전 유치면수  영구치우식유병자여부  우식 유치수  우식 유치면수  충치가 있을 경우의 수 합  \
# 0    212.0       858.0   858.0    858.0          1556.0
# 1    362.0       698.0   564.0    544.0          1556.0
# 2    283.0         0.0   109.0    117.0          1556.0
# 3    699.0         0.0    25.0     37.0          1556.0
#
#    현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  치료 받았던 유치의 충치 수에 따른 충치발생 확률  \
# 0                      0.161954                     0.136247
# 1                      0.353470                     0.382391
# 2                      0.291131                     0.298201
# 3                      0.193445                     0.183162
#
#    현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률
# 0                        0.126607
# 1                        0.209512
# 2                        0.179306
# 3                        0.484576

# %%
last_result4['치료 받았던 유치면수에 따른 충치발생 확률'] = last_result4['충전 유치면수'] / last_result4['충치가 있을 경우의 수 합'] 

last_result5 = last_result4.drop(['충전 유치면수'], axis=1)
last_result5
# Out:
#    영구치우식유병자여부  우식 유치수  우식 유치면수  충치가 있을 경우의 수 합  현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  \
# 0       858.0   858.0    858.0          1556.0                      0.161954
# 1       698.0   564.0    544.0          1556.0                      0.353470
# 2         0.0   109.0    117.0          1556.0                      0.291131
# 3         0.0    25.0     37.0          1556.0                      0.193445
#
#    치료 받았던 유치의 충치 수에 따른 충치발생 확률  현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률  \
# 0                     0.136247                        0.126607
# 1                     0.382391                        0.209512
# 2                     0.298201                        0.179306
# 3                     0.183162                        0.484576
#
#    치료 받았던 유치면수에 따른 충치발생 확률
# 0                 0.136247
# 1                 0.232648
# 2                 0.181877
# 3                 0.449229

# %%
last_result5['현재 영구치의 충치 유무에 따른 충치발생 확률'] = last_result5['영구치우식유병자여부'] / last_result5['충치가 있을 경우의 수 합'] 

last_result6 = last_result5.drop(['영구치우식유병자여부'], axis=1)
last_result6
# Out:
#    우식 유치수  우식 유치면수  충치가 있을 경우의 수 합  현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  \
# 0   858.0    858.0          1556.0                      0.161954
# 1   564.0    544.0          1556.0                      0.353470
# 2   109.0    117.0          1556.0                      0.291131
# 3    25.0     37.0          1556.0                      0.193445
#
#    치료 받았던 유치의 충치 수에 따른 충치발생 확률  현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률  \
# 0                     0.136247                        0.126607
# 1                     0.382391                        0.209512
# 2                     0.298201                        0.179306
# 3                     0.183162                        0.484576
#
#    치료 받았던 유치면수에 따른 충치발생 확률  현재 영구치의 충치 유무에 따른 충치발생 확률
# 0                 0.136247                   0.551414
# 1                 0.232648                   0.448586
# 2                 0.181877                   0.000000
# 3                 0.449229                   0.000000

# %%
last_result6['충치가 생겼던 유치수에 따른 충치발생 확률'] = last_result6['우식 유치수'] / last_result5['충치가 있을 경우의 수 합']

last_result7 = last_result6.drop(['우식 유치수'], axis=1)
last_result7
# Out:
#    우식 유치면수  충치가 있을 경우의 수 합  현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  \
# 0    858.0          1556.0                      0.161954
# 1    544.0          1556.0                      0.353470
# 2    117.0          1556.0                      0.291131
# 3     37.0          1556.0                      0.193445
#
#    치료 받았던 유치의 충치 수에 따른 충치발생 확률  현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률  \
# 0                     0.136247                        0.126607
# 1                     0.382391                        0.209512
# 2                     0.298201                        0.179306
# 3                     0.183162                        0.484576
#
#    치료 받았던 유치면수에 따른 충치발생 확률  현재 영구치의 충치 유무에 따른 충치발생 확률  충치가 생겼던 유치수에 따른 충치발생 확률
# 0                 0.136247                   0.551414                 0.551414
# 1                 0.232648                   0.448586                 0.362468
# 2                 0.181877                   0.000000                 0.070051
# ...

# %%
last_result7['현재 충치가 있는 유치의 면수에 따른 충치발생 확률'] = last_result7['우식 유치면수'] / last_result7['충치가 있을 경우의 수 합'] 

last_result8 = last_result7.drop(['우식 유치면수'], axis=1)
last_result8
# Out:
#    충치가 있을 경우의 수 합  현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  치료 받았던 유치의 충치 수에 따른 충치발생 확률  \
# 0          1556.0                      0.161954                     0.136247
# 1          1556.0                      0.353470                     0.382391
# 2          1556.0                      0.291131                     0.298201
# 3          1556.0                      0.193445                     0.183162
#
#    현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률  치료 받았던 유치면수에 따른 충치발생 확률  \
# 0                        0.126607                 0.136247
# 1                        0.209512                 0.232648
# 2                        0.179306                 0.181877
# 3                        0.484576                 0.449229
#
#    현재 영구치의 충치 유무에 따른 충치발생 확률  충치가 생겼던 유치수에 따른 충치발생 확률  \
# 0                   0.551414                 0.551414
# 1                   0.448586                 0.362468
# 2                   0.000000                 0.070051
# 3                   0.000000                 0.016067
#
# ...

# %%
last_result9 = last_result8.drop(['충치가 있을 경우의 수 합'], axis = 1)
last_result9
# Out:
#    현재까지 충치가 생겼던 유치수에 따른 충치발생 확률  치료 받았던 유치의 충치 수에 따른 충치발생 확률  \
# 0                      0.161954                     0.136247
# 1                      0.353470                     0.382391
# 2                      0.291131                     0.298201
# 3                      0.193445                     0.183162
#
#    현재까지 충치가 생겼던 유치 면수에 따른 충치발생 확률  치료 받았던 유치면수에 따른 충치발생 확률  \
# 0                        0.126607                 0.136247
# 1                        0.209512                 0.232648
# 2                        0.179306                 0.181877
# 3                        0.484576                 0.449229
#
#    현재 영구치의 충치 유무에 따른 충치발생 확률  충치가 생겼던 유치수에 따른 충치발생 확률  \
# 0                   0.551414                 0.551414
# 1                   0.448586                 0.362468
# 2                   0.000000                 0.070051
# 3                   0.000000                 0.016067
#
#    현재 충치가 있는 유치의 면수에 따른 충치발생 확률
# 0                      0.551414
# ...

# %%
last_result9.to_csv("충치 발생 확률.csv")
